# %%
import pandas as pd
df=pd.read_csv("/content/risk credit card(Data).csv")
df.head()
# Out:
#     Lim_bal Sex      Education Marriage   Age  September  August  July  June  \
# 0   20000.0   m  UnderGraduate  Married  24.0        2.0     2.0  -1.0  -1.0
# 1  120000.0   m  UnderGraduate   Single  26.0       -1.0     2.0   0.0   0.0
# 2   90000.0   m  UnderGraduate   Single  34.0        0.0     0.0   0.0   0.0
# 3   50000.0   m  UnderGraduate  Married  37.0        0.0     0.0   0.0   0.0
# 4   50000.0   f  UnderGraduate  Married  57.0       -1.0     0.0  -1.0   0.0
#
#    May  ...  Bill_amt4  Bill_amt5  Bill_amt6  Pay_amt1  Pay_amt2  Pay_amt3  \
# 0 -2.0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  0.0  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  0.0  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  0.0  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  0.0  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    Pay_amt4  Pay_amt5  Pay_amt6  Default_pay
# ...

# %%
print("Shape of data:",df.shape)
df.info()
# Out:
# Shape of data: (30000, 24)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 24 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Lim_bal      29965 non-null  float64
#  1   Sex          29965 non-null  object
#  2   Education    29965 non-null  object
#  3   Marriage     29965 non-null  object
#  4   Age          29965 non-null  float64
#  5   September    29965 non-null  float64
#  6   August       29965 non-null  float64
#  7   July         29965 non-null  float64
#  8   June         29965 non-null  float64
#  9   May          29965 non-null  float64
#  10  April        29965 non-null  float64
#  11  Bill_amt1    29965 non-null  float64
#  12  Bill_amt2    29965 non-null  float64
#  13  Bill_amt3    29965 non-null  float64
#  14  Bill_amt4    29965 non-null  float64
#  15  Bill_amt5    29965 non-null  float64
#  16  Bill_amt6    29965 non-null  float64
# ...

# %%
print("Missing values in each column:")
print(df.isnull().sum())
# Out:
# Missing values in each column:
# Lim_bal        35
# Sex            35
# Education      35
# Marriage       35
# Age            35
# September      35
# August         35
# July           35
# June           35
# May            35
# April          35
# Bill_amt1      35
# Bill_amt2      35
# Bill_amt3      35
# Bill_amt4      35
# Bill_amt5      35
# Bill_amt6      35
# Pay_amt1       35
# Pay_amt2       35
# Pay_amt3       35
# Pay_amt4       35
# Pay_amt5       35
# Pay_amt6       35
# Default_pay    35
# dtype: int64

# %%
df = df.dropna()
print("New shape after dropping missing rows:", df.shape)
# Out:
# New shape after dropping missing rows: (29965, 24)

# %%
df.describe()
# Out:
#               Lim_bal           Age     September        August          July  \
# count    29965.000000  29965.000000  29965.000000  29965.000000  29965.000000
# mean    167442.005006     35.487969     -0.016753     -0.131854     -0.164392
# std     129760.135222      9.219459      1.123492      1.196322      1.195878
# min      10000.000000     21.000000     -2.000000     -2.000000     -2.000000
# 25%      50000.000000     28.000000     -1.000000     -1.000000     -1.000000
# 50%     140000.000000     34.000000      0.000000      0.000000      0.000000
# 75%     240000.000000     41.000000      0.000000      0.000000      0.000000
# max    1000000.000000     79.000000      8.000000      8.000000      8.000000
#
#                June           May         April      Bill_amt1      Bill_amt2  \
# count  29965.000000  29965.000000  29965.000000   29965.000000   29965.000000
# mean      -0.218922     -0.264509     -0.289438   51283.009778   49236.366294
# ...

# %% [markdown]
# # Step 6: Summary Statistics
# df.describe(include='all')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# %%
sns.histplot(df['Age'], bins=30, kde=True)
plt.title("Age Distribution")
plt.show()

# %%
sns.boxplot(x=df['Lim_bal'])
plt.title("Credit Limit (Lim_bal)")
plt.show()

# %%
sns.countplot(x='Sex', data=df)
plt.title("Gender Count")
plt.show()

sns.countplot(x='Default_pay', data=df)
plt.title("Who defaulted?")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x='Default_pay', y='Lim_bal', data=df)
plt.title("Credit Limit vs Default")
plt.show()
